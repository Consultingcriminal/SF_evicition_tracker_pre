# %% [markdown]
# ### Gaining Insights From Evictions Data
#
# #### Libraries Used
# 1) Pandas - For Data Manipulation
#
# 2) Seaborn And Matplotlib - For Data Visualisation

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("dark")
sns.set_theme()
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# #### Initialising Connection to the DB

# %%
engine = create_engine("mysql+pymysql://" + "root" + ":" + "#####" + "@" + "localhost" + "/" + "sf_prod")

# %%
df = pd.read_sql('SELECT *FROM fact_evictions',engine)
df.head()
# Out:
#   eviction_key  location_key  district_key  neighborhood_key  \
# 0      AL2K001            10             6                 3
# 1      E2K2588             3             5                25
# 2      E980002            26             1                 1
# 3      E980003            22             3                 8
# 4      E980004             7             2                13
#
#    reason_group_key  file_date_key  constraints_date_key  \
# 0                25           1879                    -1
# 1                14           1835                    -1
# 2                 1           3240                    -1
# 3                28           3240                    -1
# 4                 2           3240                    -1
#
#                      street_address     latitude  longitude
# 0      1600 Block Of Howard  Street  -122.417274  37.771072
# 1        1200 Block Of 04th  Avenue   -122.46099   37.76474
# 2  1500 Block Of California  Street   -122.41986  37.790684
# 3     1600 Block Of Alabama  Street   -122.41053   37.74595
# 4       400 Block Of Leland  Avenue   -122.41249  37.713936

# %% [markdown]
# ### Lets Visualise

# %% [markdown]
# #### Rise And Fall Trend of Evictions Over The Years

# %%
eviction_trend = """
SELECT dd.year,COUNT(*) AS eviction_count
FROM sf_prod.fact_evictions fe
INNER JOIN sf_prod.dim_date dd
ON fe.file_date_key = dd.date_key
GROUP BY dd.year
ORDER BY dd.year; 
"""

trend_df = pd.read_sql(eviction_trend,engine)
p = sns.lineplot(data = trend_df, x = "year", y = "eviction_count")
p.set_title("Evicitons By Year")
p.set_xlabel("Year", fontsize = 15)
p.set_ylabel("Number Of Evictions", fontsize = 15)
# Out:
# Text(0, 0.5, 'Number Of Evictions')

# %%
eviction_trend_bm = """
SELECT dd.year,dd.quartal AS quarter,COUNT(*) AS eviction_count
FROM sf_prod.fact_evictions fe
INNER JOIN sf_prod.dim_date dd
ON fe.file_date_key = dd.date_key
GROUP BY dd.year,dd.quartal
ORDER BY dd.year; 
"""

trend_bm_df = pd.read_sql(eviction_trend_bm,engine)
p = sns.lineplot(data = trend_bm_df, x = "year", y = "eviction_count",hue = "quarter")
p.set_title("Evicitons By Year And Quarter")
p.set_xlabel("Year", fontsize = 15)
p.set_ylabel("Number Of Evictions", fontsize = 15)
# Out:
# Text(0, 0.5, 'Number Of Evictions')

# %% [markdown]
# #### Over The Past Two Years

# %%
eviction_past2 = """
SELECT dd.month,dd.year,COUNT(*) AS count
FROM sf_prod.fact_evictions fe
INNER JOIN sf_prod.dim_date dd
ON fe.file_date_key = dd.date_key
WHERE dd.date >= (SELECT DATE_SUB(MAX(date),INTERVAL 2 YEAR) FROM sf_prod.dim_date)
GROUP BY dd.month,dd.year
ORDER BY dd.year,dd.month;

"""


eviction_past2 = pd.read_sql(eviction_past2,engine)
eviction_past2.head()
eviction_past2['month_year'] = eviction_past2['month'].map(str) + "-" + eviction_past2['year'].map(str)
eviction_past2 = eviction_past2.drop(['month','year'],axis = 1)
p = sns.lineplot(data = eviction_past2, x = "month_year", y = "count")
p.set_title("Evicitons Over The Past 2 Years")
p.set_xlabel("Month-Year", fontsize = 15)
p.set_ylabel("Number Of Evictions", fontsize = 15)
p.set_xticklabels(labels=eviction_past2['month_year'], rotation=30)
# Out:
# [Text(0, 0, '1-2011'),
#  Text(1, 0, '2-2011'),
#  Text(2, 0, '3-2011'),
#  Text(3, 0, '4-2011'),
#  Text(4, 0, '5-2011'),
#  Text(5, 0, '6-2011'),
#  Text(6, 0, '7-2011'),
#  Text(7, 0, '8-2011'),
#  Text(8, 0, '9-2011'),
#  Text(9, 0, '10-2011'),
#  Text(10, 0, '11-2011'),
#  Text(11, 0, '12-2011'),
#  Text(12, 0, '1-2012'),
#  Text(13, 0, '2-2012'),
#  Text(14, 0, '3-2012'),
#  Text(15, 0, '4-2012'),
#  Text(16, 0, '5-2012'),
#  Text(17, 0, '6-2012'),
#  Text(18, 0, '7-2012'),
#  Text(19, 0, '8-2012'),
#  Text(20, 0, '9-2012'),
#  Text(21, 0, '10-2012'),
#  Text(22, 0, '11-2012'),
#  Text(23, 0, '12-2012')]

# %% [markdown]
# #### Evicitions By District And Neighborhood

# %%
eviction_dist = """
SELECT dd.district,COUNT(*) AS evictions_count
FROM sf_prod.fact_evictions fe
INNER JOIN sf_prod.dim_district dd
ON fe.district_key = dd.district_key
GROUP BY dd.district
ORDER BY COUNT(*) DESC
LIMIT 5;
"""

eviction_dist_df = pd.read_sql(eviction_dist,engine)
eviction_dist_df.head()

colors = sns.color_palette('pastel')

#create pie chart
p = plt.pie(eviction_dist_df['evictions_count'], labels = eviction_dist_df['district'], colors = colors, autopct='%.0f%%')
plt.title("Distribution of Evictions In Top 5 Districts")
plt.show()

# %%
eviction_neighborhood = """
SELECT dd.neighborhood,COUNT(*) AS evictions_count
FROM sf_prod.fact_evictions fe
INNER JOIN sf_prod.dim_neighborhood dd
ON fe.neighborhood_key = dd.neighborhood_key
GROUP BY dd.neighborhood
"""

eviction_neighborhood_df = pd.read_sql(eviction_neighborhood,engine)
eviction_neighborhood_df.head()

ax = sns.barplot(x = "evictions_count", y = "neighborhood", data = eviction_neighborhood_df)
ax.set_title("Distribution of Evictions with Neighborhoods")
ax.set_xlabel("Number Of Evictions", fontsize = 15)
ax.set_ylabel("Neighborhood", fontsize = 15)
# Out:
# Text(0, 0.5, 'Neighborhood')

# %% [markdown]
# #### Analysing Evictions Type

# %%
evictions_type = """
SELECT dr.reason_desc,COUNT(*) AS count
FROM sf_prod.fact_evictions fe
INNER JOIN sf_prod.dim_mod_reason dr
ON fe.reason_group_key = dr.reason_key
GROUP BY dr.reason_desc
ORDER BY COUNT(*) DESC
LIMIT 10;
"""

eviction_type_df = pd.read_sql(evictions_type,engine)
colors = sns.color_palette('pastel')

#create pie chart
plt.pie(eviction_type_df['count'], labels = eviction_type_df['reason_desc'], colors = colors, autopct='%.0f%%')
plt.title("Distribution of Evictions By Top 10 Eviciton_Type")
plt.show()

# %% [markdown]
# #### Analyzing After How many breaches is an Eviciton_Notice Served

# %%
evictions_type_count = """
SELECT dr.reason_desc,COUNT(*) AS count
FROM sf_prod.fact_evictions fe
INNER JOIN sf_prod.dim_mod_reason dr
ON fe.reason_group_key = dr.reason_key
GROUP BY dr.reason_desc
ORDER BY COUNT(*) DESC;
"""

eviction_type_count_df = pd.read_sql(evictions_type_count,engine)
eviction_type_count_df['Number_of_evictions'] = eviction_type_count_df['reason_desc'].str.count("[|]")+1
evictions_by_count = eviction_type_count_df
evictions_by_count.head()
eviction_grpby_count = evictions_by_count.groupby(by=["Number_of_evictions"], dropna=False).sum()
eviction_grpby_count = eviction_grpby_count.reset_index(level=['Number_of_evictions'])
eviction_grpby_count.head()
ax = sns.barplot(x = "Number_of_evictions", y = "count", data = eviction_grpby_count)
ax.set_title("After How many breaches is the notice served?")
ax.set_xlabel("Number of Breaches", fontsize = 15)
ax.set_ylabel("Number of Evictions Served", fontsize = 15)
# Out:
# Text(0, 0.5, 'Number of Evictions Served')
